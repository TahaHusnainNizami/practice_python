# %% [markdown]
# **print se hum python me koi bhi chz as a output likhte hn**

# %%
print("HELLO , Taha")
# Out:
# HELLO , Taha

# %% [markdown]
# input aik built in func hota h

# %%
input('whats age')

# %%
print('Taha',name,',you r young good for u')
